# %% [markdown]
# # Clase 4 - Segmentacion tiramisu 16 bits
# ![picture](https://drive.google.com/uc?id=1Ar6KpqlsLxcLlnOrXPx6QZejStP6bV9P)

# %% [markdown]
# ## Pre requisitos

# %% [markdown]
# Se actualiza fastai descargando y ejecutando el script *colab*

# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %% [markdown]
# Dar permiso para acceder a mi Drive

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# Nos aseguramos que cualquier cambio en una librería es recargado automáticamente y que que cualquier gráfica o imagen se muestre aquí

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# Importamos las librerías necesarias

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.utils.mem import *

# %% [markdown]
# ## Curso 4 - Segmentacion tiramisu 16 bits

# %% [markdown]
# Hay un data set de imágenes basadas en Camvid, pero con imágenes más pequeñas y menos etiquetas

# %% [markdown]
# ### Descarga del dataset

# %%
# !git clone https://github.com/alexgkendall/SegNet-Tutorial.git
# Out:
# Cloning into 'SegNet-Tutorial'...
# remote: Enumerating objects: 2785, done.
# remote: Total 2785 (delta 0), reused 0 (delta 0), pack-reused 2785
# Receiving objects: 100% (2785/2785), 340.84 MiB | 35.60 MiB/s, done.
# Resolving deltas: 100% (81/81), done.

# %%
path = Path('/content/SegNet-Tutorial/CamVid')
path.ls()
# Out:
# [PosixPath('/content/SegNet-Tutorial/CamVid/test.txt'),
#  PosixPath('/content/SegNet-Tutorial/CamVid/test'),
#  PosixPath('/content/SegNet-Tutorial/CamVid/valannot'),
#  PosixPath('/content/SegNet-Tutorial/CamVid/train'),
#  PosixPath('/content/SegNet-Tutorial/CamVid/val'),
#  PosixPath('/content/SegNet-Tutorial/CamVid/trainannot'),
#  PosixPath('/content/SegNet-Tutorial/CamVid/train.txt'),
#  PosixPath('/content/SegNet-Tutorial/CamVid/val.txt'),
#  PosixPath('/content/SegNet-Tutorial/CamVid/testannot')]

# %% [markdown]
# ### Se crea el dataset

# %% [markdown]
# Obtenemos los nombres de las imágenes

# %%
fnames = get_image_files(path/'val')
fnames[:3]
# Out:
# [PosixPath('/content/SegNet-Tutorial/CamVid/val/0016E5_08117.png'),
#  PosixPath('/content/SegNet-Tutorial/CamVid/val/0016E5_08027.png'),
#  PosixPath('/content/SegNet-Tutorial/CamVid/val/0016E5_07959.png')]

# %% [markdown]
# Los nombres de las etiquetas

# %%
lbl_names = get_image_files(path/'valannot')
lbl_names[:3]
# Out:
# [PosixPath('/content/SegNet-Tutorial/CamVid/valannot/0016E5_08117.png'),
#  PosixPath('/content/SegNet-Tutorial/CamVid/valannot/0016E5_08027.png'),
#  PosixPath('/content/SegNet-Tutorial/CamVid/valannot/0016E5_07959.png')]

# %% [markdown]
# Parece que tienen el mismo nombre.
#
# Por lo que creamos una función para obtener el nombre de la imagen segmentada a partir del nombre de la imagen sin segmentar

# %%
def get_y_fn(x): return Path(str(x.parent)+'annot')/x.name

# %% [markdown]
# Vemos una imagen sin segmentar

# %%
img_f = fnames[0]
img = open_image(img_f)
img.show(figsize=(5,5))

# %% [markdown]
# Vemos la misma imagen segmentada

# %%
mask = open_mask(get_y_fn(img_f))
mask.show(figsize=(5,5), alpha=1, title='Imagen segmentada')

# %% [markdown]
# Vemos como son las matrices de las imágenes segmentadas y sin segmentar

# %%
img_size = np.array(img.shape[1:])
src_size = np.array(mask.shape[1:])

print(img_size)
print(src_size)
# Out:
# [360 480]
# [360 480]

# %% [markdown]
# Obtenemos los códigos de los números

# %%
codes = array(['Sky', 'Building', 'Pole', 'Road', 'Sidewalk', 'Tree',
    'Sign', 'Fence', 'Car', 'Pedestrian', 'Cyclist', 'Void'])

# %%
size = src_size//2

bs = 32
#bs = 4

# %% [markdown]
# Creamos el dataset

# %%
src = (SegmentationItemList.from_folder(path)
       .split_by_folder(valid='val')
       .label_from_func(get_y_fn, classes=codes))

# %% [markdown]
# Al hacer las transformaciones indicamos que se hagan las mismas en la imagen segmentada

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
data.show_batch(2, figsize=(10,7))

# %%
data.show_batch(2, figsize=(10,7), ds_type=DatasetType.Valid)

# %% [markdown]
# ### Se crea el modelo

# %% [markdown]
# Se crea un diccionario con los códigos

# %%
name2id = {v:k for k,v in enumerate(codes)}
void_code = name2id['Void']

name2id
# Out:
# {'Building': 1,
#  'Car': 8,
#  'Cyclist': 10,
#  'Fence': 7,
#  'Pedestrian': 9,
#  'Pole': 2,
#  'Road': 3,
#  'Sidewalk': 4,
#  'Sign': 6,
#  'Sky': 0,
#  'Tree': 5,
#  'Void': 11}

# %% [markdown]
# Se crea la función con la que se harán las métricas

# %%
def acc_camvid(input, target):
    target = target.squeeze(1)  # The output array is input array, but with all or a subset of the dimensions of length 1 removed
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %%
metrics=acc_camvid

# %%
# weight decay
wd=1e-2

# %% [markdown]
# Se define el modelo

# %% [markdown]
# ![unet](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd, bottle=True).to_fp16()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(FloatProgress(value=0.0, max=87306240.0), HTML(value='')))

# %% [markdown]
# ### Entrenamiento

# %% [markdown]
# #### Imagenes reducidas

# %%
print(src_size)
print(size)
# Out:
# [360 480]
# [180 240]

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [6/10 02:22<01:35]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.557164</td>
#       <td>#na#</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.464874</td>
#       <td>#na#</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.214655</td>
#       <td>#na#</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.324748</td>
#       <td>#na#</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.680547</td>
#       <td>#na#</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.354867</td>
#       <td>#na#</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       45.45% [5/11 00:08<00:10 3.7401]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=2e-4

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.048497</td>
#       <td>2.561656</td>
#       <td>0.101499</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.658624</td>
#       <td>2.090819</td>
#       <td>0.423087</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.186554</td>
#       <td>1.321749</td>
#       <td>0.602120</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.801311</td>
#       <td>0.962769</td>
#       <td>0.732319</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.526374</td>
#       <td>0.843976</td>
#       <td>0.762892</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.310698</td>
#       <td>0.834415</td>
#       <td>0.765870</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.159381</td>
#       <td>0.679216</td>
#       <td>0.825493</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.031316</td>
#       <td>0.617285</td>
#       <td>0.846407</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.922617</td>
#       <td>0.591373</td>
#       <td>0.838842</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.836407</td>
#       <td>0.578050</td>
#       <td>0.842940</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()
learn.recorder.plot_lr()
learn.recorder.plot_metrics()

# %%
learn.save('stage-1_tiramisu_16b')

# %%
learn.show_results(rows=3, figsize=(10,7))

# %%
learn.unfreeze()
lrs = slice(lr/100,lr)
learn.fit_one_cycle(12, lrs, pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.517544</td>
#       <td>0.556924</td>
#       <td>0.850794</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.512192</td>
#       <td>0.551748</td>
#       <td>0.848870</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.507041</td>
#       <td>0.522129</td>
#       <td>0.854248</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.500399</td>
#       <td>0.485812</td>
#       <td>0.865534</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.497274</td>
#       <td>0.488366</td>
#       <td>0.857538</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.487055</td>
#       <td>0.473475</td>
#       <td>0.868998</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.484506</td>
#       <td>0.528944</td>
#       <td>0.842274</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.477753</td>
#       <td>0.475878</td>
#       <td>0.864480</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.468064</td>
#       <td>0.420657</td>
#       <td>0.872062</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.459785</td>
#       <td>0.439284</td>
#       <td>0.861878</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.444710</td>
#       <td>0.383196</td>
#       <td>0.885923</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.427919</td>
#       <td>0.387181</td>
#       <td>0.879929</td>
#       <td>00:21</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(lr/100)
print(lr)
# Out:
# 2e-06
# 0.0002

# %%
learn.recorder.plot_losses()
learn.recorder.plot_lr()
learn.recorder.plot_metrics()

# %%
learn.save('stage-2_tiramisu_16b');

# %%
learn.show_results(rows=3, figsize=(10,7))

# %%
drive_folder = '/content/drive/My\ Drive/Colab\ Notebooks/Curso\ fastai/04\ Segmentacion'

# %%
# !cp /content/SegNet-Tutorial/CamVid/models/stage-2_tiramisu_16b.pth {drive_folder}

# %% [markdown]
# #### Imagenes a tamaño real

# %% [markdown]
# ##### Reinicio del kernel

# %% [markdown]
# Para evitar problemas de 'out of memory' es necesario reiniciar el kernel y volver a ejecutar algunas celdas para volver a tener algunas variables

# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.utils.mem import *

# %%
# !git clone https://github.com/alexgkendall/SegNet-Tutorial.git
# Out:
# Cloning into 'SegNet-Tutorial'...
# remote: Enumerating objects: 2785, done.
# remote: Total 2785 (delta 0), reused 0 (delta 0), pack-reused 2785
# Receiving objects: 100% (2785/2785), 340.84 MiB | 13.94 MiB/s, done.
# Resolving deltas: 100% (81/81), done.

# %%
path = Path('/content/SegNet-Tutorial/CamVid')

# %%
drive_folder = '/content/drive/My\ Drive/Colab\ Notebooks/Curso\ fastai/04\ Segmentacion'

# %%
# !mkdir /content/SegNet-Tutorial/CamVid/models

# %%
# !cp {drive_folder}/stage-2_tiramisu_16b.pth /content/SegNet-Tutorial/CamVid/models

# %%
fnames = get_image_files(path/'val')
fnames[:3]
# Out:
# [PosixPath('/content/SegNet-Tutorial/CamVid/val/0016E5_08117.png'),
#  PosixPath('/content/SegNet-Tutorial/CamVid/val/0016E5_08027.png'),
#  PosixPath('/content/SegNet-Tutorial/CamVid/val/0016E5_07959.png')]

# %%
lbl_names = get_image_files(path/'valannot')
lbl_names[:3]
# Out:
# [PosixPath('/content/SegNet-Tutorial/CamVid/valannot/0016E5_08117.png'),
#  PosixPath('/content/SegNet-Tutorial/CamVid/valannot/0016E5_08027.png'),
#  PosixPath('/content/SegNet-Tutorial/CamVid/valannot/0016E5_07959.png')]

# %%
def get_y_fn(x): return Path(str(x.parent)+'annot')/x.name

# %%
img_f = fnames[0]
mask = open_mask(get_y_fn(img_f))

# %%
src_size = np.array(mask.shape[1:])

# %%
codes = array(['Sky', 'Building', 'Pole', 'Road', 'Sidewalk', 'Tree',
    'Sign', 'Fence', 'Car', 'Pedestrian', 'Cyclist', 'Void'])

# %%
src = (SegmentationItemList.from_folder(path)
       .split_by_folder(valid='val')
       .label_from_func(get_y_fn, classes=codes))

# %%
name2id = {v:k for k,v in enumerate(codes)}
void_code = name2id['Void']

def acc_camvid(input, target):
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %%
metrics=acc_camvid
wd=1e-2

# %% [markdown]
# ##### Entrenamiento

# %%
size = src_size
bs=16

# %%
print(src_size)
print(size)
# Out:
# [360 480]
# [360 480]

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd, bottle=True).to_fp16()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(FloatProgress(value=0.0, max=87306240.0), HTML(value='')))

# %%
learn.load('stage-2_tiramisu_16b');

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       40.00% [2/5 00:52<01:18]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.430242</td>
#       <td>#na#</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.421416</td>
#       <td>#na#</td>
#       <td>00:18</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='22' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       36.36% [8/22 00:07<00:13 1.1892]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.431073</td>
#       <td>0.395471</td>
#       <td>0.877142</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.404078</td>
#       <td>0.432430</td>
#       <td>0.882233</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.385216</td>
#       <td>0.379884</td>
#       <td>0.890789</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.394286</td>
#       <td>0.455867</td>
#       <td>0.848674</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.423915</td>
#       <td>0.470749</td>
#       <td>0.874296</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.412304</td>
#       <td>0.445799</td>
#       <td>0.856524</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.393601</td>
#       <td>0.383053</td>
#       <td>0.885278</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.381034</td>
#       <td>0.309776</td>
#       <td>0.907474</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.366768</td>
#       <td>0.277764</td>
#       <td>0.914081</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.336345</td>
#       <td>0.256810</td>
#       <td>0.919478</td>
#       <td>00:21</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()
learn.recorder.plot_lr()
learn.recorder.plot_metrics()

# %%
learn.save('stage-1-big_tiramisu_16b')

# %%
learn.load('stage-1-big_tiramisu_16b')

# %%
lrs = slice(lr/1000,lr/10)

# %%
learn.unfreeze()
learn.fit_one_cycle(10, lrs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.265823</td>
#       <td>0.251535</td>
#       <td>0.920045</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.262543</td>
#       <td>0.260236</td>
#       <td>0.916060</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.256281</td>
#       <td>0.259857</td>
#       <td>0.921762</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.253146</td>
#       <td>0.236468</td>
#       <td>0.931308</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.244194</td>
#       <td>0.234398</td>
#       <td>0.927945</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.237655</td>
#       <td>0.233856</td>
#       <td>0.928474</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.231204</td>
#       <td>0.234375</td>
#       <td>0.928187</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.225398</td>
#       <td>0.237027</td>
#       <td>0.928310</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.221379</td>
#       <td>0.232549</td>
#       <td>0.929145</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.218155</td>
#       <td>0.236079</td>
#       <td>0.927779</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results(rows=3, figsize=(10,10))

# %%
learn.save('stage-2-big_tiramisu_16b')

# %%
learn.export()

# %% [markdown]
# ### Copiar el modelo a nuestro Drive

# %%
drive_folder = '/content/drive/My\ Drive/Colab\ Notebooks/Curso\ fastai/04\ Segmentacion'

# %%
# !mv /content/SegNet-Tutorial/CamVid/export.pkl /content/SegNet-Tutorial/CamVid/segmentacion_tiramisu_16b.pkl

# %%
# !cp /content/SegNet-Tutorial/CamVid/segmentacion_tiramisu_16b.pkl {drive_folder}

# %%
print('fin')
# Out:
# fin
